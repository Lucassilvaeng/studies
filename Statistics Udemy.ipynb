# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import numpy as np
import statsmodels.api as sm

# %%
df = pd.read_csv(r'/home/lucas/Documents/data_sets/reg.csv')

# %%
df_vin_usa = df.drop(['year','UK GDP growth'],axis =1 )
df_vin_usa['US GDP growth']
# Out:
# 0    2.53
# 1    1.60
# 2    2.22
# 3    1.49
# 4    2.43
# 5    2.43
# Name: US GDP growth, dtype: float64

# %%
df_vin_usa['US GDP growth'].describe()
# Out:
# count    6.000000
# mean     2.116667
# std      0.455529
# min      1.490000
# 25%      1.755000
# 50%      2.325000
# 75%      2.430000
# max      2.530000
# Name: US GDP growth, dtype: float64

# %%
df_vin_usa.corr('kendall')
# Out:
#                    Vin Diesel movies  US GDP growth
# Vin Diesel movies           1.000000       0.222375
# US GDP growth               0.222375       1.000000

# %%
plt.scatter(df_vin_usa['Vin Diesel movies'],df_vin_usa['US GDP growth'])

# %%
df_students = pd.read_csv(r'/home/lucas/Documents/data_sets/gpa_sat.csv')
df_students
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# 5   1670  2.91
# 6   1764  3.00
# 7   1764  3.00
# 8   1792  3.01
# 9   1850  3.01
# 10  1735  3.02
# 11  1775  3.07
# 12  1735  3.08
# 13  1712  3.08
# 14  1773  3.12
# 15  1872  3.17
# 16  1755  3.17
# 17  1674  3.17
# 18  1842  3.17
# 19  1786  3.19
# 20  1761  3.19
# 21  1722  3.19
# 22  1663  3.20
# 23  1687  3.21
# 24  1974  3.24
# 25  1826  3.28
# 26  1787  3.28
# 27  1821  3.28
# 28  2020  3.28
# 29  1794  3.28
# ..   ...   ...
# 54  1879  3.44
# 55  1887  3.47
# 56  1730  3.47
# 57  1953  3.47
# 58  1781  3.47
# 59  1891  3.48
# 60  1964  3.49
# 61  1808  3.49
# 62  1893  3.50
# 63  2041  3.51
# 64  1893  3.51
# 65  1832  3.52
# 66  1850  3.52
# 67  1934  3.54
# 68  1861  3.58
# 69  1931  3.58
# 70  1933  3.59
# 71  1778  3.59
# 72  1975  3.60
# 73  1934  3.60
# 74  2021  3.61
# 75  2015  3.62
# 76  1997  3.64
# 77  2020  3.65
# 78  1843  3.71
# 79  1936  3.71
# ...

# %%
df_students.corr()
# Out:
#           SAT       GPA
# SAT  1.000000  0.637184
# GPA  0.637184  1.000000

# %%
plt.scatter(df_students['SAT'], df_students['GPA'])
xlim =2100
ylim = 4

# %%
df_students['SAT'].shape
# Out:
# (84,)

# %%
results = sm.RLM(df_students['SAT'], df_students['GPA']).fit()
# Print a nice summary of the regression. That's one of the strong points of statsmodels -> the summaries
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                     Robust linear Model Regression Results
# ...
# Dep. Variable:                    SAT   No. Observations:                   84
# Model:                            RLM   Df Residuals:                       83
# Method:                          IRLS   Df Model:                            0
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Sun, 15 Sep 2019
# Time:                        18:18:07
# No. Iterations:                     8
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# GPA          551.3369      3.373    163.448      0.000     544.726     557.948
# ...
#
# If the model instance has been used for another fit with different fit
# parameters, then the fit options might not be the correct ones anymore .
# """

# %%
dir(sm)
# Out:
# ['BayesGaussMI',
#  'BinomialBayesMixedGLM',
#  'Factor',
#  'GEE',
#  'GLM',
#  'GLMGam',
#  'GLS',
#  'GLSAR',
#  'GeneralizedPoisson',
#  'Logit',
#  'MANOVA',
#  'MI',
#  'MICE',
#  'MICEData',
#  'MNLogit',
#  'MixedLM',
#  'NegativeBinomial',
#  'NegativeBinomialP',
#  'NominalGEE',
#  'OLS',
#  'OrdinalGEE',
#  'PCA',
#  'PHReg',
#  'Poisson',
#  'PoissonBayesMixedGLM',
#  'ProbPlot',
#  'Probit',
#  'QuantReg',
#  'RLM',
#  'RecursiveLS',
#  'SurvfuncRight',
#  'WLS',
#  'ZeroInflatedGeneralizedPoisson',
#  'ZeroInflatedNegativeBinomialP',
#  'ZeroInflatedPoisson',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__version__',
#  'add_constant',
#  'categorical',
#  'cov_struct',
#  'datasets',
#  'distributions',
#  'duration',
#  'emplike',
#  'families',
#  'formula',
#  'gam',
#  'genmod',
#  'graphics',
#  'iolib',
#  'load',
#  'multivariate',
#  'nonparametric',
#  'qqline',
# ...
